# %%
#importuri
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import collections
import imageio.v3 as iio
from sklearn.metrics import confusion_matrix, classification_report,accuracy_score, make_scorer
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Sequential, Model, load_model
from keras.layers import Activation, Dropout, Flatten, Dense,Conv2D, MaxPooling2D
from keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.utils import to_categorical
from keras.applications.densenet import DenseNet121
import tensorflow as tf
from sklearn.utils import class_weight
from keras import regularizers
from sklearn.model_selection import GridSearchCV

# %%
#Load data
path = "/kaggle/input/unibuc-ml-202325/"
train_csv = pd.read_csv(path + "train.csv")
val_csv = pd.read_csv(path + "val.csv")
test_csv = pd.read_csv(path + "test.csv")

#Extracting data
y_train = np.array(train_csv['Class'])
y_val = np.array(val_csv['Class'])

#Convrtim la one-hot-encoded
y_train_encoded = to_categorical(y_train, num_classes=96)
y_val_encoded = to_categorical(y_val, num_classes=96)

display(train_csv.head())
#Vizualizam datele pe care urmeaza sa fie antrenat modelul
plt.hist(x = train_csv['Class'],bins = 96)
plt.show()
# Out:
#        Image  Class
# 0  12953.png     38
# 1  02978.png     76
# 2  10718.png     18
# 3  01916.png     16
# 4  15254.png     53

# %%
#Vizualizam clasele de imagini care au frecventa cea mai mare
frequency_list_train = collections.Counter(train_csv['Class'])
print(frequency_list_train.most_common(3))

frequency_list_val = collections.Counter(val_csv['Class'])
print(frequency_list_val.most_common(3))
# Out:
# [(27, 350), (38, 239), (81, 232)]
# [(27, 36), (38, 22), (20, 15)]

# %% [markdown]
# **Load X_train, X_val, X_test, apoi convertim la numpy-arrays**

# %%
# Load validation images
X_val = np.array([iio.imread(path + "val_images/" + image) for image in val_csv['Image']])

# Load training images
X_train = np.array([iio.imread(path + "train_images/" + image) for image in train_csv['Image']])

# Load test images
X_test = np.array([iio.imread(path + "test_images/" + image) for image in test_csv['Image']])

# %% [markdown]
# **Normalizam datele inainte de a fi folosite **

# %%
from sklearn import preprocessing

# Reshape pentru a obtine vectori cu shape-ul - numar_de_sample-uri si features
X_train_reshaped = X_train.reshape(X_train.shape[0], -1)
X_val_reshaped = X_val.reshape(X_val.shape[0], -1)
X_test_reshaped = X_test.reshape(X_test.shape[0], -1)

# Creem un obiect de tip StandardScaler
scaler = preprocessing.StandardScaler()

# Sclare fit
scaler.fit(X_train_reshaped)

# Normlizam datele
X_train_normalized = scaler.transform(X_train_reshaped)
X_val_normalized = scaler.transform(X_val_reshaped)
X_test_normalized = scaler.transform(X_test_reshaped)

# Reshape pentru a aduce datele la forma initiala
X_train_normalized = X_train_normalized.reshape(X_train.shape)
X_val_normalized = X_val_normalized.reshape(X_val.shape)
X_test_normalized = X_test_normalized.reshape(X_test.shape)

# %%
width, height = X_train[0].shape[:2]
train_samples_no = len(X_train)
val_samples_no = len(X_val)
epochs = 100
batch_size = 50
n_classes = len(frequency_list_train)
early_stop = EarlyStopping(monitor='val_loss', patience=10, verbose=1, min_delta=1e-4)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=5, verbose=1, min_delta=1e-4)

# %%
train_datagen = ImageDataGenerator(
    rotation_range=10,
    width_shift_range=0.1,
    height_shift_range=0.1,
    brightness_range=[0.8, 1.2],
    zoom_range=0.2,
    horizontal_flip=True
)

train_generator = train_datagen.flow(
    X_train_normalized,
    y_train_encoded,  # provide the target data
    batch_size=batch_size,
    shuffle=True
)


val_datagen = ImageDataGenerator()

val_generator = val_datagen.flow(
    X_val_normalized,
    y_val_encoded,  # provide the target data
    batch_size=batch_size
)

# %%
# Calculate class weights
class_weights = class_weight.compute_class_weight('balanced', classes = np.unique(y_train), y = y_train)

# Convert class weights to a dictionary
class_weights_dict = dict(enumerate(class_weights))

# %%
from keras.wrappers.scikit_learn import KerasClassifier
from sklearn.model_selection import GridSearchCV
from keras.optimizers import Adam

# Define a function that builds the model
def build_model(learning_rate):
    model = Sequential()
    model.add(DenseNet121(include_top=False, pooling='avg', weights=None))
    model.add(Dense(2500, kernel_regularizer=regularizers.l2(0.01)))
    model.add(Activation('relu'))
    model.add(Dense(1000, kernel_regularizer=regularizers.l2(0.01)))
    model.add(Activation('relu'))
    model.add(Dense(n_classes, activation='softmax'))

    for layer in model.layers[0].layers:
        layer.trainable = True
    
    optimizer = Adam(learning_rate=learning_rate)
    model.compile(loss='categorical_crossentropy', optimizer=optimizer, metrics=['acc'])
    
    return model

# Create a KerasClassifier wrapper
model_wrapper = KerasClassifier(build_fn=build_model)

# Define the parameter grid
param_grid = {
    'learning_rate': [0.001, 0.01, 0.1],
    'batch_size': [32, 64, 128]
}

# Create the grid search object
grid_search = GridSearchCV(model_wrapper, param_grid, cv=3, scoring=scoring)

# Perform the grid search
grid_search.fit(X_train_normalized, y_train_encoded)

# Get the best hyperparameters
best_params = grid_search.best_params_
print(bes)
# Out:
# /tmp/ipykernel_28/2152778337.py:24: DeprecationWarning: KerasClassifier is deprecated, use Sci-Keras (https://github.com/adriangb/scikeras) instead. See https://www.adriangb.com/scikeras/stable/migration.html for help migrating.
#   model_wrapper = KerasClassifier(build_fn=build_model)
# 250/250 [==============================] - 24s 40ms/step - loss: 6.6372 - acc: 0.0884
# 125/125 [==============================] - 4s 14ms/step
# /opt/conda/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:778: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/site-packages/sklearn/model_selection/_validation.py", line 767, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "/opt/conda/lib/python3.10/site-packages/sklearn/metrics/_scorer.py", line 234, in __call__
#     return self._score(
#   File "/opt/conda/lib/python3.10/site-packages/sklearn/metrics/_scorer.py", line 282, in _score
#     return self._sign * self._score_func(y_true, y_pred, **self._kwargs)
#   File "/opt/conda/lib/python3.10/site-packages/sklearn/utils/_param_validation.py", line 192, in wrapper
#     return func(*args, **kwargs)
#   File "/opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py", line 221, in accuracy_score
#     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#   File "/opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py", line 95, in _check_targets
#     raise ValueError(
# ValueError: Classification metrics can't handle a mix of multilabel-indicator and multiclass targets
#
#   warnings.warn(
# 250/250 [==============================] - 22s 41ms/step - loss: 6.6543 - acc: 0.1047
# 125/125 [==============================] - 3s 13ms/step
# /opt/conda/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:778: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/site-packages/sklearn/model_selection/_validation.py", line 767, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "/opt/conda/lib/python3.10/site-packages/sklearn/metrics/_scorer.py", line 234, in __call__
#     return self._score(
#   File "/opt/conda/lib/python3.10/site-packages/sklearn/metrics/_scorer.py", line 282, in _score
#     return self._sign * self._score_func(y_true, y_pred, **self._kwargs)
#   File "/opt/conda/lib/python3.10/site-packages/sklearn/utils/_param_validation.py", line 192, in wrapper
#     return func(*args, **kwargs)
#   File "/opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py", line 221, in accuracy_score
#     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#   File "/opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py", line 95, in _check_targets
#     raise ValueError(
# ValueError: Classification metrics can't handle a mix of multilabel-indicator and multiclass targets
#
#   warnings.warn(
# 250/250 [==============================] - 21s 42ms/step - loss: 6.9054 - acc: 0.0946
# 125/125 [==============================] - 3s 13ms/step
# /opt/conda/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:778: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/site-packages/sklearn/model_selection/_validation.py", line 767, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "/opt/conda/lib/python3.10/site-packages/sklearn/metrics/_scorer.py", line 234, in __call__
#     return self._score(
#   File "/opt/conda/lib/python3.10/site-packages/sklearn/metrics/_scorer.py", line 282, in _score
#     return self._sign * self._score_func(y_true, y_pred, **self._kwargs)
#   File "/opt/conda/lib/python3.10/site-packages/sklearn/utils/_param_validation.py", line 192, in wrapper
#     return func(*args, **kwargs)
#   File "/opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py", line 221, in accuracy_score
#     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#   File "/opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py", line 95, in _check_targets
#     raise ValueError(
# ValueError: Classification metrics can't handle a mix of multilabel-indicator and multiclass targets
#
#   warnings.warn(
# 250/250 [==============================] - 22s 42ms/step - loss: 9.5059 - acc: 0.0321
# 125/125 [==============================] - 3s 13ms/step
# /opt/conda/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:778: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/site-packages/sklearn/model_selection/_validation.py", line 767, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "/opt/conda/lib/python3.10/site-packages/sklearn/metrics/_scorer.py", line 234, in __call__
#     return self._score(
#   File "/opt/conda/lib/python3.10/site-packages/sklearn/metrics/_scorer.py", line 282, in _score
#     return self._sign * self._score_func(y_true, y_pred, **self._kwargs)
#   File "/opt/conda/lib/python3.10/site-packages/sklearn/utils/_param_validation.py", line 192, in wrapper
#     return func(*args, **kwargs)
#   File "/opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py", line 221, in accuracy_score
#     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#   File "/opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py", line 95, in _check_targets
#     raise ValueError(
# ValueError: Classification metrics can't handle a mix of multilabel-indicator and multiclass targets
#
#   warnings.warn(
# 250/250 [==============================] - 22s 42ms/step - loss: 9.1811 - acc: 0.0289
# 125/125 [==============================] - 3s 13ms/step
# /opt/conda/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:778: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/site-packages/sklearn/model_selection/_validation.py", line 767, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "/opt/conda/lib/python3.10/site-packages/sklearn/metrics/_scorer.py", line 234, in __call__
#     return self._score(
#   File "/opt/conda/lib/python3.10/site-packages/sklearn/metrics/_scorer.py", line 282, in _score
#     return self._sign * self._score_func(y_true, y_pred, **self._kwargs)
#   File "/opt/conda/lib/python3.10/site-packages/sklearn/utils/_param_validation.py", line 192, in wrapper
#     return func(*args, **kwargs)
#   File "/opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py", line 221, in accuracy_score
#     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#   File "/opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py", line 95, in _check_targets
#     raise ValueError(
# ValueError: Classification metrics can't handle a mix of multilabel-indicator and multiclass targets
#
#   warnings.warn(
# 250/250 [==============================] - 22s 40ms/step - loss: 9.3194 - acc: 0.0286
# 125/125 [==============================] - 3s 13ms/step
# /opt/conda/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:778: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/site-packages/sklearn/model_selection/_validation.py", line 767, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "/opt/conda/lib/python3.10/site-packages/sklearn/metrics/_scorer.py", line 234, in __call__
#     return self._score(
#   File "/opt/conda/lib/python3.10/site-packages/sklearn/metrics/_scorer.py", line 282, in _score
#     return self._sign * self._score_func(y_true, y_pred, **self._kwargs)
#   File "/opt/conda/lib/python3.10/site-packages/sklearn/utils/_param_validation.py", line 192, in wrapper
#     return func(*args, **kwargs)
#   File "/opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py", line 221, in accuracy_score
#     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#   File "/opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py", line 95, in _check_targets
#     raise ValueError(
# ValueError: Classification metrics can't handle a mix of multilabel-indicator and multiclass targets
#
#   warnings.warn(
# 250/250 [==============================] - 22s 41ms/step - loss: 737.6010 - acc: 0.0269
# 125/125 [==============================] - 4s 13ms/step
# /opt/conda/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:778: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/site-packages/sklearn/model_selection/_validation.py", line 767, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "/opt/conda/lib/python3.10/site-packages/sklearn/metrics/_scorer.py", line 234, in __call__
#     return self._score(
#   File "/opt/conda/lib/python3.10/site-packages/sklearn/metrics/_scorer.py", line 282, in _score
#     return self._sign * self._score_func(y_true, y_pred, **self._kwargs)
#   File "/opt/conda/lib/python3.10/site-packages/sklearn/utils/_param_validation.py", line 192, in wrapper
#     return func(*args, **kwargs)
#   File "/opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py", line 221, in accuracy_score
#     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#   File "/opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py", line 95, in _check_targets
#     raise ValueError(
# ValueError: Classification metrics can't handle a mix of multilabel-indicator and binary targets
#
#   warnings.warn(
# 250/250 [==============================] - 22s 41ms/step - loss: 679.8513 - acc: 0.0249
# 125/125 [==============================] - 4s 14ms/step
# /opt/conda/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:778: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/site-packages/sklearn/model_selection/_validation.py", line 767, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "/opt/conda/lib/python3.10/site-packages/sklearn/metrics/_scorer.py", line 234, in __call__
#     return self._score(
#   File "/opt/conda/lib/python3.10/site-packages/sklearn/metrics/_scorer.py", line 282, in _score
#     return self._sign * self._score_func(y_true, y_pred, **self._kwargs)
#   File "/opt/conda/lib/python3.10/site-packages/sklearn/utils/_param_validation.py", line 192, in wrapper
#     return func(*args, **kwargs)
#   File "/opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py", line 221, in accuracy_score
#     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#   File "/opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py", line 95, in _check_targets
#     raise ValueError(
# ValueError: Classification metrics can't handle a mix of multilabel-indicator and binary targets
#
#   warnings.warn(
# 250/250 [==============================] - 22s 42ms/step - loss: 829.1154 - acc: 0.0272
# 125/125 [==============================] - 3s 13ms/step
# /opt/conda/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:778: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/site-packages/sklearn/model_selection/_validation.py", line 767, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "/opt/conda/lib/python3.10/site-packages/sklearn/metrics/_scorer.py", line 234, in __call__
#     return self._score(
#   File "/opt/conda/lib/python3.10/site-packages/sklearn/metrics/_scorer.py", line 282, in _score
#     return self._sign * self._score_func(y_true, y_pred, **self._kwargs)
#   File "/opt/conda/lib/python3.10/site-packages/sklearn/utils/_param_validation.py", line 192, in wrapper
#     return func(*args, **kwargs)
#   File "/opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py", line 221, in accuracy_score
#     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#   File "/opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py", line 95, in _check_targets
#     raise ValueError(
# ValueError: Classification metrics can't handle a mix of multilabel-indicator and binary targets
#
#   warnings.warn(
# 125/125 [==============================] - 21s 55ms/step - loss: 8.6168 - acc: 0.1015
# 125/125 [==============================] - 3s 13ms/step
# /opt/conda/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:778: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/site-packages/sklearn/model_selection/_validation.py", line 767, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "/opt/conda/lib/python3.10/site-packages/sklearn/metrics/_scorer.py", line 234, in __call__
#     return self._score(
#   File "/opt/conda/lib/python3.10/site-packages/sklearn/metrics/_scorer.py", line 282, in _score
#     return self._sign * self._score_func(y_true, y_pred, **self._kwargs)
#   File "/opt/conda/lib/python3.10/site-packages/sklearn/utils/_param_validation.py", line 192, in wrapper
#     return func(*args, **kwargs)
#   File "/opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py", line 221, in accuracy_score
#     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#   File "/opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py", line 95, in _check_targets
#     raise ValueError(
# ValueError: Classification metrics can't handle a mix of multilabel-indicator and multiclass targets
#
#   warnings.warn(
# 125/125 [==============================] - 18s 56ms/step - loss: 8.2215 - acc: 0.1350
# 125/125 [==============================] - 4s 13ms/step
# /opt/conda/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:778: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/site-packages/sklearn/model_selection/_validation.py", line 767, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "/opt/conda/lib/python3.10/site-packages/sklearn/metrics/_scorer.py", line 234, in __call__
#     return self._score(
#   File "/opt/conda/lib/python3.10/site-packages/sklearn/metrics/_scorer.py", line 282, in _score
#     return self._sign * self._score_func(y_true, y_pred, **self._kwargs)
#   File "/opt/conda/lib/python3.10/site-packages/sklearn/utils/_param_validation.py", line 192, in wrapper
#     return func(*args, **kwargs)
#   File "/opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py", line 221, in accuracy_score
#     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#   File "/opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py", line 95, in _check_targets
#     raise ValueError(
# ValueError: Classification metrics can't handle a mix of multilabel-indicator and multiclass targets
#
#   warnings.warn(
# 125/125 [==============================] - 18s 56ms/step - loss: 8.2584 - acc: 0.1351
# 125/125 [==============================] - 3s 13ms/step
# /opt/conda/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:778: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/site-packages/sklearn/model_selection/_validation.py", line 767, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "/opt/conda/lib/python3.10/site-packages/sklearn/metrics/_scorer.py", line 234, in __call__
#     return self._score(
#   File "/opt/conda/lib/python3.10/site-packages/sklearn/metrics/_scorer.py", line 282, in _score
#     return self._sign * self._score_func(y_true, y_pred, **self._kwargs)
#   File "/opt/conda/lib/python3.10/site-packages/sklearn/utils/_param_validation.py", line 192, in wrapper
#     return func(*args, **kwargs)
#   File "/opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py", line 221, in accuracy_score
#     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#   File "/opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py", line 95, in _check_targets
#     raise ValueError(
# ValueError: Classification metrics can't handle a mix of multilabel-indicator and multiclass targets
#
#   warnings.warn(
# 125/125 [==============================] - 18s 57ms/step - loss: 11.7639 - acc: 0.0310
# 125/125 [==============================] - 3s 12ms/step
# /opt/conda/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:778: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/site-packages/sklearn/model_selection/_validation.py", line 767, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "/opt/conda/lib/python3.10/site-packages/sklearn/metrics/_scorer.py", line 234, in __call__
#     return self._score(
#   File "/opt/conda/lib/python3.10/site-packages/sklearn/metrics/_scorer.py", line 282, in _score
#     return self._sign * self._score_func(y_true, y_pred, **self._kwargs)
#   File "/opt/conda/lib/python3.10/site-packages/sklearn/utils/_param_validation.py", line 192, in wrapper
#     return func(*args, **kwargs)
#   File "/opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py", line 221, in accuracy_score
#     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#   File "/opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py", line 95, in _check_targets
#     raise ValueError(
# ValueError: Classification metrics can't handle a mix of multilabel-indicator and multiclass targets
#
#   warnings.warn(
# 125/125 [==============================] - 19s 57ms/step - loss: 12.5788 - acc: 0.0258
# 125/125 [==============================] - 3s 13ms/step
# /opt/conda/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:778: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/site-packages/sklearn/model_selection/_validation.py", line 767, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "/opt/conda/lib/python3.10/site-packages/sklearn/metrics/_scorer.py", line 234, in __call__
#     return self._score(
#   File "/opt/conda/lib/python3.10/site-packages/sklearn/metrics/_scorer.py", line 282, in _score
#     return self._sign * self._score_func(y_true, y_pred, **self._kwargs)
#   File "/opt/conda/lib/python3.10/site-packages/sklearn/utils/_param_validation.py", line 192, in wrapper
#     return func(*args, **kwargs)
#   File "/opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py", line 221, in accuracy_score
#     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#   File "/opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py", line 95, in _check_targets
#     raise ValueError(
# ValueError: Classification metrics can't handle a mix of multilabel-indicator and multiclass targets
#
#   warnings.warn(
# 125/125 [==============================] - 19s 54ms/step - loss: 11.5724 - acc: 0.0336
# 125/125 [==============================] - 4s 13ms/step
# /opt/conda/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:778: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/site-packages/sklearn/model_selection/_validation.py", line 767, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "/opt/conda/lib/python3.10/site-packages/sklearn/metrics/_scorer.py", line 234, in __call__
#     return self._score(
#   File "/opt/conda/lib/python3.10/site-packages/sklearn/metrics/_scorer.py", line 282, in _score
#     return self._sign * self._score_func(y_true, y_pred, **self._kwargs)
#   File "/opt/conda/lib/python3.10/site-packages/sklearn/utils/_param_validation.py", line 192, in wrapper
#     return func(*args, **kwargs)
#   File "/opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py", line 221, in accuracy_score
#     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#   File "/opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py", line 95, in _check_targets
#     raise ValueError(
# ValueError: Classification metrics can't handle a mix of multilabel-indicator and multiclass targets
#
#   warnings.warn(
# 125/125 [==============================] - 19s 55ms/step - loss: 1257.3281 - acc: 0.0164
# 125/125 [==============================] - 4s 16ms/step
# /opt/conda/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:778: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/site-packages/sklearn/model_selection/_validation.py", line 767, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "/opt/conda/lib/python3.10/site-packages/sklearn/metrics/_scorer.py", line 234, in __call__
#     return self._score(
#   File "/opt/conda/lib/python3.10/site-packages/sklearn/metrics/_scorer.py", line 282, in _score
#     return self._sign * self._score_func(y_true, y_pred, **self._kwargs)
#   File "/opt/conda/lib/python3.10/site-packages/sklearn/utils/_param_validation.py", line 192, in wrapper
#     return func(*args, **kwargs)
#   File "/opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py", line 221, in accuracy_score
#     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#   File "/opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py", line 95, in _check_targets
#     raise ValueError(
# ValueError: Classification metrics can't handle a mix of multilabel-indicator and multiclass targets
#
#   warnings.warn(
# 125/125 [==============================] - 19s 55ms/step - loss: 1207.5142 - acc: 0.0256
# 125/125 [==============================] - 4s 13ms/step
# /opt/conda/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:778: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/site-packages/sklearn/model_selection/_validation.py", line 767, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "/opt/conda/lib/python3.10/site-packages/sklearn/metrics/_scorer.py", line 234, in __call__
#     return self._score(
#   File "/opt/conda/lib/python3.10/site-packages/sklearn/metrics/_scorer.py", line 282, in _score
#     return self._sign * self._score_func(y_true, y_pred, **self._kwargs)
#   File "/opt/conda/lib/python3.10/site-packages/sklearn/utils/_param_validation.py", line 192, in wrapper
#     return func(*args, **kwargs)
#   File "/opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py", line 221, in accuracy_score
#     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#   File "/opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py", line 95, in _check_targets
#     raise ValueError(
# ValueError: Classification metrics can't handle a mix of multilabel-indicator and multiclass targets
#
#   warnings.warn(
# 125/125 [==============================] - 18s 54ms/step - loss: 1217.7209 - acc: 0.0172
# 125/125 [==============================] - 4s 14ms/step
# /opt/conda/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:778: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/site-packages/sklearn/model_selection/_validation.py", line 767, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "/opt/conda/lib/python3.10/site-packages/sklearn/metrics/_scorer.py", line 234, in __call__
#     return self._score(
#   File "/opt/conda/lib/python3.10/site-packages/sklearn/metrics/_scorer.py", line 282, in _score
#     return self._sign * self._score_func(y_true, y_pred, **self._kwargs)
#   File "/opt/conda/lib/python3.10/site-packages/sklearn/utils/_param_validation.py", line 192, in wrapper
#     return func(*args, **kwargs)
#   File "/opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py", line 221, in accuracy_score
#     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#   File "/opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py", line 95, in _check_targets
#     raise ValueError(
# ValueError: Classification metrics can't handle a mix of multilabel-indicator and binary targets
#
#   warnings.warn(
# 63/63 [==============================] - 20s 83ms/step - loss: 11.8271 - acc: 0.1446
# 125/125 [==============================] - 3s 13ms/step
# /opt/conda/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:778: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/site-packages/sklearn/model_selection/_validation.py", line 767, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "/opt/conda/lib/python3.10/site-packages/sklearn/metrics/_scorer.py", line 234, in __call__
#     return self._score(
#   File "/opt/conda/lib/python3.10/site-packages/sklearn/metrics/_scorer.py", line 282, in _score
#     return self._sign * self._score_func(y_true, y_pred, **self._kwargs)
#   File "/opt/conda/lib/python3.10/site-packages/sklearn/utils/_param_validation.py", line 192, in wrapper
#     return func(*args, **kwargs)
#   File "/opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py", line 221, in accuracy_score
#     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#   File "/opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py", line 95, in _check_targets
#     raise ValueError(
# ValueError: Classification metrics can't handle a mix of multilabel-indicator and multiclass targets
#
#   warnings.warn(
# 63/63 [==============================] - 18s 84ms/step - loss: 11.7848 - acc: 0.1529
# 125/125 [==============================] - 3s 13ms/step
# /opt/conda/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:778: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/site-packages/sklearn/model_selection/_validation.py", line 767, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "/opt/conda/lib/python3.10/site-packages/sklearn/metrics/_scorer.py", line 234, in __call__
#     return self._score(
#   File "/opt/conda/lib/python3.10/site-packages/sklearn/metrics/_scorer.py", line 282, in _score
#     return self._sign * self._score_func(y_true, y_pred, **self._kwargs)
#   File "/opt/conda/lib/python3.10/site-packages/sklearn/utils/_param_validation.py", line 192, in wrapper
#     return func(*args, **kwargs)
#   File "/opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py", line 221, in accuracy_score
#     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#   File "/opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py", line 95, in _check_targets
#     raise ValueError(
# ValueError: Classification metrics can't handle a mix of multilabel-indicator and multiclass targets
#
#   warnings.warn(
# 63/63 [==============================] - 18s 82ms/step - loss: 11.7651 - acc: 0.1482
# 125/125 [==============================] - 3s 13ms/step
# /opt/conda/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:778: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/site-packages/sklearn/model_selection/_validation.py", line 767, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "/opt/conda/lib/python3.10/site-packages/sklearn/metrics/_scorer.py", line 234, in __call__
#     return self._score(
#   File "/opt/conda/lib/python3.10/site-packages/sklearn/metrics/_scorer.py", line 282, in _score
#     return self._sign * self._score_func(y_true, y_pred, **self._kwargs)
#   File "/opt/conda/lib/python3.10/site-packages/sklearn/utils/_param_validation.py", line 192, in wrapper
#     return func(*args, **kwargs)
#   File "/opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py", line 221, in accuracy_score
#     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#   File "/opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py", line 95, in _check_targets
#     raise ValueError(
# ValueError: Classification metrics can't handle a mix of multilabel-indicator and multiclass targets
#
#   warnings.warn(
# 63/63 [==============================] - 18s 82ms/step - loss: 15.3921 - acc: 0.0288
# 125/125 [==============================] - 3s 13ms/step
# /opt/conda/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:778: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/site-packages/sklearn/model_selection/_validation.py", line 767, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "/opt/conda/lib/python3.10/site-packages/sklearn/metrics/_scorer.py", line 234, in __call__
#     return self._score(
#   File "/opt/conda/lib/python3.10/site-packages/sklearn/metrics/_scorer.py", line 282, in _score
#     return self._sign * self._score_func(y_true, y_pred, **self._kwargs)
#   File "/opt/conda/lib/python3.10/site-packages/sklearn/utils/_param_validation.py", line 192, in wrapper
#     return func(*args, **kwargs)
#   File "/opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py", line 221, in accuracy_score
#     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#   File "/opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py", line 95, in _check_targets
#     raise ValueError(
# ValueError: Classification metrics can't handle a mix of multilabel-indicator and multiclass targets
#
#   warnings.warn(
# 63/63 [==============================] - 17s 83ms/step - loss: 16.4079 - acc: 0.0351
# 125/125 [==============================] - 5s 13ms/step
# /opt/conda/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:778: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/site-packages/sklearn/model_selection/_validation.py", line 767, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "/opt/conda/lib/python3.10/site-packages/sklearn/metrics/_scorer.py", line 234, in __call__
#     return self._score(
#   File "/opt/conda/lib/python3.10/site-packages/sklearn/metrics/_scorer.py", line 282, in _score
#     return self._sign * self._score_func(y_true, y_pred, **self._kwargs)
#   File "/opt/conda/lib/python3.10/site-packages/sklearn/utils/_param_validation.py", line 192, in wrapper
#     return func(*args, **kwargs)
#   File "/opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py", line 221, in accuracy_score
#     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#   File "/opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py", line 95, in _check_targets
#     raise ValueError(
# ValueError: Classification metrics can't handle a mix of multilabel-indicator and binary targets
#
#   warnings.warn(
# 63/63 [==============================] - 17s 83ms/step - loss: 16.2898 - acc: 0.0259
# 125/125 [==============================] - 4s 14ms/step
# /opt/conda/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:778: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/site-packages/sklearn/model_selection/_validation.py", line 767, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "/opt/conda/lib/python3.10/site-packages/sklearn/metrics/_scorer.py", line 234, in __call__
#     return self._score(
#   File "/opt/conda/lib/python3.10/site-packages/sklearn/metrics/_scorer.py", line 282, in _score
#     return self._sign * self._score_func(y_true, y_pred, **self._kwargs)
#   File "/opt/conda/lib/python3.10/site-packages/sklearn/utils/_param_validation.py", line 192, in wrapper
#     return func(*args, **kwargs)
#   File "/opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py", line 221, in accuracy_score
#     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#   File "/opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py", line 95, in _check_targets
#     raise ValueError(
# ValueError: Classification metrics can't handle a mix of multilabel-indicator and multiclass targets
#
#   warnings.warn(
# 63/63 [==============================] - 17s 83ms/step - loss: 1966.1476 - acc: 0.0134
# 125/125 [==============================] - 3s 13ms/step
# /opt/conda/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:778: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/site-packages/sklearn/model_selection/_validation.py", line 767, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "/opt/conda/lib/python3.10/site-packages/sklearn/metrics/_scorer.py", line 234, in __call__
#     return self._score(
#   File "/opt/conda/lib/python3.10/site-packages/sklearn/metrics/_scorer.py", line 282, in _score
#     return self._sign * self._score_func(y_true, y_pred, **self._kwargs)
#   File "/opt/conda/lib/python3.10/site-packages/sklearn/utils/_param_validation.py", line 192, in wrapper
#     return func(*args, **kwargs)
#   File "/opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py", line 221, in accuracy_score
#     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#   File "/opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py", line 95, in _check_targets
#     raise ValueError(
# ValueError: Classification metrics can't handle a mix of multilabel-indicator and binary targets
#
#   warnings.warn(
# 63/63 [==============================] - 18s 83ms/step - loss: 1928.7966 - acc: 0.0201
# 125/125 [==============================] - 3s 13ms/step
# /opt/conda/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:778: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/site-packages/sklearn/model_selection/_validation.py", line 767, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "/opt/conda/lib/python3.10/site-packages/sklearn/metrics/_scorer.py", line 234, in __call__
#     return self._score(
#   File "/opt/conda/lib/python3.10/site-packages/sklearn/metrics/_scorer.py", line 282, in _score
#     return self._sign * self._score_func(y_true, y_pred, **self._kwargs)
#   File "/opt/conda/lib/python3.10/site-packages/sklearn/utils/_param_validation.py", line 192, in wrapper
#     return func(*args, **kwargs)
#   File "/opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py", line 221, in accuracy_score
#     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#   File "/opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py", line 95, in _check_targets
#     raise ValueError(
# ValueError: Classification metrics can't handle a mix of multilabel-indicator and binary targets
#
#   warnings.warn(
# 63/63 [==============================] - 18s 83ms/step - loss: 1787.2435 - acc: 0.0192
# 125/125 [==============================] - 3s 13ms/step
# /opt/conda/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:778: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/site-packages/sklearn/model_selection/_validation.py", line 767, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "/opt/conda/lib/python3.10/site-packages/sklearn/metrics/_scorer.py", line 234, in __call__
#     return self._score(
#   File "/opt/conda/lib/python3.10/site-packages/sklearn/metrics/_scorer.py", line 282, in _score
#     return self._sign * self._score_func(y_true, y_pred, **self._kwargs)
#   File "/opt/conda/lib/python3.10/site-packages/sklearn/utils/_param_validation.py", line 192, in wrapper
#     return func(*args, **kwargs)
#   File "/opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py", line 221, in accuracy_score
#     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#   File "/opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py", line 95, in _check_targets
#     raise ValueError(
# ValueError: Classification metrics can't handle a mix of multilabel-indicator and binary targets
#
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/model_selection/_search.py:952: UserWarning: One or more of the test scores are non-finite: [nan nan nan nan nan nan nan nan nan]
#   warnings.warn(
# 375/375 [==============================] - 28s 40ms/step - loss: 5.6970 - acc: 0.0890

# %%
print(best_params)
# Out:
# {'batch_size': 32, 'learning_rate': 0.001}

# %%
history = model.fit(
    train_generator,
    epochs=epochs,
    validation_data=val_generator,
    validation_steps=val_samples_no // batch_size,
    callbacks=[early_stop,reduce_lr],
    class_weight=class_weights_dict)
# Out:
# Epoch 1/100
# 240/240 [==============================] - 29s 88ms/step - loss: 3.4283 - acc: 0.1673 - val_loss: 2.4032 - val_acc: 0.3600 - lr: 0.0010
# Epoch 2/100
# 240/240 [==============================] - 21s 87ms/step - loss: 2.1539 - acc: 0.4074 - val_loss: 1.8951 - val_acc: 0.4660 - lr: 0.0010
# Epoch 3/100
# 240/240 [==============================] - 23s 96ms/step - loss: 1.6797 - acc: 0.5192 - val_loss: 1.3788 - val_acc: 0.5980 - lr: 0.0010
# Epoch 4/100
# 240/240 [==============================] - 21s 88ms/step - loss: 1.3788 - acc: 0.5893 - val_loss: 1.4291 - val_acc: 0.6000 - lr: 0.0010
# Epoch 5/100
# 240/240 [==============================] - 21s 86ms/step - loss: 1.1945 - acc: 0.6400 - val_loss: 1.1917 - val_acc: 0.6450 - lr: 0.0010
# Epoch 6/100
# 240/240 [==============================] - 21s 89ms/step - loss: 1.0371 - acc: 0.6793 - val_loss: 1.3014 - val_acc: 0.6320 - lr: 0.0010
# Epoch 7/100
# 240/240 [==============================] - 20s 85ms/step - loss: 0.9473 - acc: 0.7036 - val_loss: 1.4949 - val_acc: 0.5830 - lr: 0.0010
# Epoch 8/100
# 240/240 [==============================] - 22s 90ms/step - loss: 0.8680 - acc: 0.7262 - val_loss: 1.2448 - val_acc: 0.6380 - lr: 0.0010
# Epoch 9/100
# 240/240 [==============================] - 21s 86ms/step - loss: 0.8058 - acc: 0.7402 - val_loss: 1.0907 - val_acc: 0.6750 - lr: 0.0010
# Epoch 10/100
# 240/240 [==============================] - 21s 88ms/step - loss: 0.7052 - acc: 0.7688 - val_loss: 1.1185 - val_acc: 0.6780 - lr: 0.0010
# Epoch 11/100
# 240/240 [==============================] - 21s 86ms/step - loss: 0.6687 - acc: 0.7798 - val_loss: 0.9803 - val_acc: 0.7060 - lr: 0.0010
# Epoch 12/100
# 240/240 [==============================] - 21s 87ms/step - loss: 0.6387 - acc: 0.7879 - val_loss: 1.2567 - val_acc: 0.6640 - lr: 0.0010
# Epoch 13/100
# 240/240 [==============================] - 20s 85ms/step - loss: 0.5974 - acc: 0.8006 - val_loss: 0.9591 - val_acc: 0.7280 - lr: 0.0010
# Epoch 14/100
# 240/240 [==============================] - 21s 88ms/step - loss: 0.5628 - acc: 0.8104 - val_loss: 1.4993 - val_acc: 0.6150 - lr: 0.0010
# Epoch 15/100
# 240/240 [==============================] - 21s 87ms/step - loss: 0.5453 - acc: 0.8202 - val_loss: 0.8798 - val_acc: 0.7570 - lr: 0.0010
# Epoch 16/100
# 240/240 [==============================] - 21s 90ms/step - loss: 0.5082 - acc: 0.8313 - val_loss: 0.9093 - val_acc: 0.7510 - lr: 0.0010
# Epoch 17/100
# 240/240 [==============================] - 22s 90ms/step - loss: 0.4757 - acc: 0.8388 - val_loss: 0.9837 - val_acc: 0.7200 - lr: 0.0010
# Epoch 18/100
# 240/240 [==============================] - 21s 87ms/step - loss: 0.4598 - acc: 0.8408 - val_loss: 0.9618 - val_acc: 0.7390 - lr: 0.0010
# Epoch 19/100
# 240/240 [==============================] - 21s 88ms/step - loss: 0.4438 - acc: 0.8506 - val_loss: 1.0470 - val_acc: 0.7170 - lr: 0.0010
# Epoch 20/100
# 240/240 [==============================] - ETA: 0s - loss: 0.4328 - acc: 0.8507
# Epoch 20: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 240/240 [==============================] - 21s 87ms/step - loss: 0.4328 - acc: 0.8507 - val_loss: 1.0687 - val_acc: 0.7140 - lr: 0.0010
# Epoch 21/100
# 240/240 [==============================] - 21s 87ms/step - loss: 0.2739 - acc: 0.9068 - val_loss: 0.8466 - val_acc: 0.7610 - lr: 1.0000e-04
# Epoch 22/100
# 240/240 [==============================] - 21s 89ms/step - loss: 0.2379 - acc: 0.9208 - val_loss: 0.8563 - val_acc: 0.7670 - lr: 1.0000e-04
# Epoch 23/100
# 240/240 [==============================] - 21s 90ms/step - loss: 0.2298 - acc: 0.9199 - val_loss: 0.8504 - val_acc: 0.7680 - lr: 1.0000e-04
# Epoch 24/100
# 240/240 [==============================] - 21s 89ms/step - loss: 0.2142 - acc: 0.9243 - val_loss: 0.8772 - val_acc: 0.7730 - lr: 1.0000e-04
# Epoch 25/100
# 240/240 [==============================] - 21s 89ms/step - loss: 0.2042 - acc: 0.9266 - val_loss: 0.8429 - val_acc: 0.7800 - lr: 1.0000e-04
# Epoch 26/100
# 240/240 [==============================] - 21s 87ms/step - loss: 0.2022 - acc: 0.9285 - val_loss: 0.8677 - val_acc: 0.7870 - lr: 1.0000e-04
# Epoch 27/100
# 240/240 [==============================] - 21s 88ms/step - loss: 0.2014 - acc: 0.9299 - val_loss: 0.8515 - val_acc: 0.7800 - lr: 1.0000e-04
# Epoch 28/100
# 240/240 [==============================] - 21s 87ms/step - loss: 0.1927 - acc: 0.9322 - val_loss: 0.8814 - val_acc: 0.7760 - lr: 1.0000e-04
# Epoch 29/100
# 240/240 [==============================] - 22s 90ms/step - loss: 0.1837 - acc: 0.9332 - val_loss: 0.9091 - val_acc: 0.7720 - lr: 1.0000e-04
# Epoch 30/100
# 240/240 [==============================] - ETA: 0s - loss: 0.1833 - acc: 0.9353
# Epoch 30: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# 240/240 [==============================] - 20s 85ms/step - loss: 0.1833 - acc: 0.9353 - val_loss: 0.9709 - val_acc: 0.7670 - lr: 1.0000e-04
# Epoch 31/100
# 240/240 [==============================] - 21s 88ms/step - loss: 0.1700 - acc: 0.9401 - val_loss: 0.9298 - val_acc: 0.7770 - lr: 1.0000e-05
# Epoch 32/100
# 240/240 [==============================] - 21s 88ms/step - loss: 0.1709 - acc: 0.9401 - val_loss: 0.8972 - val_acc: 0.7800 - lr: 1.0000e-05
# Epoch 33/100
# 240/240 [==============================] - 21s 88ms/step - loss: 0.1638 - acc: 0.9447 - val_loss: 0.9094 - val_acc: 0.7770 - lr: 1.0000e-05
# Epoch 34/100
# 240/240 [==============================] - 21s 88ms/step - loss: 0.1649 - acc: 0.9427 - val_loss: 0.9090 - val_acc: 0.7790 - lr: 1.0000e-05
# Epoch 35/100
# 240/240 [==============================] - ETA: 0s - loss: 0.1593 - acc: 0.9430
# Epoch 35: ReduceLROnPlateau reducing learning rate to 1.0000000656873453e-06.
# 240/240 [==============================] - 20s 85ms/step - loss: 0.1593 - acc: 0.9430 - val_loss: 0.8874 - val_acc: 0.7800 - lr: 1.0000e-05
# Epoch 35: early stopping

# %%
#obtinerea predictiilor pe datele de validare
y_pred = model.predict(X_val_normalized)
y_pred_labels = np.argmax(y_pred, axis=1)
accuracy = accuracy_score(y_val, y_pred_labels)
print("Accuracy:", accuracy*100)

# %%
misclassified_samples = []
for i in range(len(y_val)):
    if y_pred_labels[i] != y_val[i]:
        misclassified_samples.append((i, y_pred_labels[i], y_val[i]))

for sample in misclassified_samples:
    index = sample[0]
    predicted_label = sample[1]
    true_label = sample[2]
    print(f"Sample {index}: Predicted label: {predicted_label}, True label: {true_label}")

# %% [markdown]
# **Obtinem si reprezentam matricea de confuzie**

# %%
cm = confusion_matrix(y_val, y_pred_labels)
plt.figure(figsize=(10, 8))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues")
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.title('Confusion Matrix')
plt.show()

# %%
sub_pred = model.predict(X_test_normalized)
sub_pred_labels = np.argmax(sub_pred, axis=1)
submission = test_csv.copy()  
submission['Class'] = sub_pred_labels

# %%
submission.to_csv('submission.csv',index = False)

# %% [markdown]
# **Venim cu o noua idee de optimizare: class_weights - Atribuirea unor ponderi mai mari clasei minoritare face ca modelul să îi acorde mai multă atenție în timpul optimizării, dându-i efectiv mai multă importanță.**
